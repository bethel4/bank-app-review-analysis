# %% [markdown]
# #### Load Data

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
df = pd.read_csv("../data/sentiment_themes.csv")
df.head()
# Out:
#                                 review  rating        date         bank  \
# 0                                 መቸሸጠ       5  2025-06-03  Dashen Bank
# 1                                  wow       5  2025-06-03  Dashen Bank
# 2                                gadaa       5  2025-06-01  Dashen Bank
# 3  Massive upgrade from the Amole app.       5  2025-05-31  Dashen Bank
# 4                                 good       4  2025-05-31  Dashen Bank
#
#         source sentiment_label  sentiment_score   identified_theme
# 0  Google Play        negative         0.697057              Other
# 1  Google Play        positive         0.999592              Other
# 2  Google Play        negative         0.721146              Other
# 3  Google Play        positive         0.964642              Other
# 4  Google Play        positive         0.999816  Positive Feedback

# %% [markdown]
# #### Bar Plot of Sentiment by Bank

# %%
sns.countplot(data=df, x="bank", hue="sentiment_label")
plt.title("Sentiment Distribution per Bank")
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("../visuals/sentiment_distribution.png")
plt.show()

# %% [markdown]
# #### WordCloud

# %%
positive_text = " ".join(df[df["sentiment_label"] == "positive"]["review"])
wordcloud = WordCloud(width=800, height=400, background_color="white").generate(positive_text)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("Positive Review Word Cloud")
plt.savefig("../visuals/positive_wordcloud.png")
plt.show()

# %% [markdown]
# ### Insight: Transaction Speed is a Top Driver
# Dashen Bank had a large number of positive reviews related to "transfer" and "speed", indicating that quick transaction handling is a major satisfaction driver.
#
# ### Pain Point: Login Errors
# BOA users frequently complained about login or access issues, particularly after recent updates.
